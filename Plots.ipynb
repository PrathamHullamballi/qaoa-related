# %%
# LINEAR GRAPHS 
# AVERAGED FOR 100 VALUES FOR EACH 100 LAYERS

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layers.csv')
e = pd.read_csv('entropyseed.csv')
g = pd.read_csv('layerslin4.csv')
f = pd.read_csv('entropylin4.csv')
p = pd.read_csv('layerslin6.csv')
s = pd.read_csv('entropylin6.csv')
plt.scatter(l,e, s=10, label='8 nodes')
plt.scatter(p, s, s=10, label='6 nodes')
plt.scatter(g,f, s=10, label='4 nodes')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title("Linear Graph")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.legend()
plt.show()

# %%
# 3-REGULAR GRAPHS
# averaged over 100 values for each 100 layers

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layers3reg4.csv')
e = pd.read_csv('entropy3reg4.csv')
g = pd.read_csv('layers3reg6.csv')
f = pd.read_csv('entropy3reg6.csv')
a = pd.read_csv('layers3reg8.csv')
b = pd.read_csv('entropy3reg8.csv')
plt.scatter(l,e, s=10, label='4 nodes')
plt.scatter(g,f, s=10, label='6 nodes')
plt.scatter(a, b, s=10, label='8 nodes')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0) 
plt.title("3-regular Graphs")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()

# %%
# COMPLETE GRAPHS
# averaged over 100 values for each 50 layers

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layerscom8.csv')
e = pd.read_csv('entropycom8.csv')
g = pd.read_csv('layerscom4.csv')
f = pd.read_csv('entropycom4.csv')
plt.scatter(l,e, s=10, label='8 nodes')
plt.scatter(g,f, s=10, label='4 nodes')
plt.legend()
plt.title("Complete Graph")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()

# %%
# ERDOS-RENYI GRAPH FOR 8 NODES
# averaged it over 100 values for each 100 layers

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
a = pd.read_csv('layersrenyi8.csv')
b = pd.read_csv('entropyrenyi8.csv')
c = pd.read_csv('layersrenyi8p3.csv')
d = pd.read_csv('entropyrenyi8p3.csv')
e = pd.read_csv('layersrenyi8p7.csv')
f = pd.read_csv('entropyrenyi8p7.csv')
plt.scatter(e,f, s=10, label='p=0.7')
plt.scatter(a,b, s=10, label='p=0.5')
plt.scatter(c,d, s=10, label='p=0.2')
plt.legend() 
plt.title("Erdos Renyi Graph With 8 Nodes")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()

# %%
# ERDOS-RENI GRAPH FOR 10 NODES
# averaged it over 100 values for each 100 layers

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = pd.read_csv('layersrenyi10.csv')
y = pd.read_csv('entropyrenyi10.csv')
w = pd.read_csv('layersrenyi10p4.csv')
v = pd.read_csv('entropyrenyi10p4.csv')
a = pd.read_csv('layersrenyi10p6.csv')
b = pd.read_csv('entropyrenyi10p6.csv')


plt.scatter(x, y, s=10, label='p=0.2')
plt.scatter(w, v, s=10, label='p=0.4')
plt.scatter(a, b, s=10, label='p=0.6')
plt.legend() 
plt.title("Erdos Renyi Graph With 10 Nodes")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()

# %%
#ERDOS-RENI GRAPH FOR 8 AND 10 NODES

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layersrenyi8.csv')
e = pd.read_csv('entropyrenyi8.csv')
g = pd.read_csv('layersrenyi8p7.csv')
f = pd.read_csv('entropyrenyi8p7.csv')
b = pd.read_csv('layersrenyi8p3.csv')
c = pd.read_csv('entropyrenyi8p3.csv')
plt.scatter(l,e, s=10, label='(n,p)=(8,0.5)')
plt.scatter(g, f, s=10, label='(n,p)=(8,0.7)')
plt.scatter(b, c, s=10, label='(n,p)=(8,0.3)')
plt.legend() 
plt.title("Erdos Renyi Graph With 8 and 10 Nodes")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
#plt.show()

x = pd.read_csv('layersrenyi10.csv')
y = pd.read_csv('entropyrenyi10.csv')
w = pd.read_csv('layersrenyi10p4.csv')
v = pd.read_csv('entropyrenyi10p4.csv')
u = pd.read_csv('layersrenyi10p6.csv')
i = pd.read_csv('entropyrenyi10p6.csv')
plt.scatter(x, y, s=10, label='(n,p)=(10,0.2)')
plt.scatter(w, v, s=10, label='(n,p)=(10,0.4)')
plt.scatter(u, i, s=10, label='(n,p)=(10,0.6)')
plt.legend()
#plt.title("Erdos Renyi Graph With 10 Nodes")
#plt.xlabel("Layers")
#plt.ylabel("Entanglement Entropy")
plt.show()

# %%
# BARABASI-ALBERT GRAPHS


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layersBG10M1.csv')
e = pd.read_csv('entropyBG10M1.csv')
g = pd.read_csv('layersBG10M9.csv')
f = pd.read_csv('entropyBG10M9.csv')
a = pd.read_csv('layersBG10M7.csv')
b = pd.read_csv('entropyBG10M7.csv')
c = pd.read_csv('layersBG10M5.csv')
d = pd.read_csv('entropyBG10M5.csv')
i = pd.read_csv('layersBG10M3.csv')
h = pd.read_csv('entropyBG10M3.csv')
plt.scatter(l,e, s=10, label='BG10 M1')
plt.scatter(i,h, s=10, label='BG10 M3')
plt.scatter(c,d, s=10, label='BG10 M5')
plt.scatter(a,b, s=10, label='BG10 M7')
plt.scatter(g,f, s=10, label='BG10 M9')


plt.legend() 
plt.title("10 noded Barabasi-Albert Graph")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()

# %%
# LINEAR GRAPH UNDER BUT-FLIP NOISE

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('layersbitnoiselin6.csv')
e = pd.read_csv('entropybitnoiselin6.csv')
g = pd.read_csv('layerslin6.csv')
f = pd.read_csv('entropylin6.csv')
a = pd.read_csv('layersbitnoise315lin4.csv')
b = pd.read_csv('entropybitnoise315lin4.csv')
plt.scatter(l,e, s=10, label='Under Bit-Flip Noise (.03, .1, .05)')
plt.scatter(g,f, s=10, label='No Noise')
plt.scatter(a,b, s=10, label='Under Bit-Flip Noise (.3, .1, .5)')
plt.legend() 
plt.title("Bit Flip Channel on RQAOA on 6 noded linear graph")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()


plt.scatter(g,f, s=10, label='No Noise')
plt.scatter(l,e, s=10, label='Under Bit-Flip Noise (.03,.1,.05)')
plt.title("Bit Flip Channel with (0.03, 0.1, 0.05) on RQAOA with 6 noded linear graph")
plt.legend()
plt.show()


plt.scatter(g,f, s=10, label='No Noise')
plt.scatter(a,b, s=10, label='Under Bit-Flip Noise (.3, .1, .5)')
plt.title("Bit Flip Channel with (0.3, 0.1, 0.5) on RQAOA on 6 noded linear graph")
plt.legend()
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# Randomised and Optimised cases for Entanglement Entropy For 6 Noded Linear Graph

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#l = pd.read_csv('layers.csv')
#e = pd.read_csv('entropyseed.csv')
#g = pd.read_csv('layerslin4.csv')
#f = pd.read_csv('entropylin4.csv')
p = pd.read_csv('layerslin6.csv')
s = pd.read_csv('entropylin6.csv')
y = pd.read_csv('optimizedlayers.csv')
z = pd.read_csv('optimized.csv')
a = pd.read_csv('50optimised.csv')
b = pd.read_csv('50opti.csv')
c = pd.read_csv('optimisedentropybitnoise315lin6.csv')
d = pd.read_csv('optimisedlayersbitnoise315lin6.csv')
#plt.scatter(l,e, s=10, label='8 nodes')
plt.scatter(p, s, s=10, label='Randomised')
plt.scatter(y, z, s=10, label='Optimised100')
plt.scatter(b, a, s=10, label='Optimised50')
#plt.scatter(d, c, s=10, label='Optimised 50 Bit-Flip 0.3, 0.1, 0.5')
#plt.scatter(g,f, s=10, label='4 nodes')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title("Linear Graph")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.legend()
plt.show()

# %%
# Randomised and Optimised cases for Entanglement Entropy For 6 Noded 3-Regular Graph

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
l = pd.read_csv('optimisedlayers3reg6.csv')
e = pd.read_csv('optimisedentropy3reg6.csv')
g = pd.read_csv('layers3reg6.csv')
f = pd.read_csv('entropy3reg6.csv')
plt.scatter(l,e, s=10, label='6 nodes optimised')
plt.scatter(g,f, s=10, label='6 nodes randomized')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0) 
plt.title("3-regular Graphs")
plt.xlabel("Layers")
plt.ylabel("Entanglement Entropy")
plt.show()
